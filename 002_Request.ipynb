# %%
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-opus-4-7"

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Me das una idea para pintar"
        }
    ]
)

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)
    # Low temperature - more predictable
    # High temperature - more creative   answer = chat(messages, temperature=1.0)
    
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

print(message.content[0].text)
# Out:
# ¡Claro! Aquí va una idea sencilla pero con mucho impacto visual:
#
# ## 🌅 **Paisaje minimalista con silueta**
#
# **Qué pintar:** Un atardecer con degradado de colores y la silueta negra de un árbol, montaña o persona en primer plano.
#
# **Materiales:**
# - Acrílicos o acuarelas
# - Lienzo, cartulina o papel grueso
# - Pinceles (uno plano y uno fino)
#
# **Pasos:**
# 1. **Fondo degradado:** Pinta franjas horizontales mezclando colores cálidos (amarillo → naranja → rosa → violeta). Difumina mientras esté húmedo.
# 2. **Deja secar bien.**
# 3. **Silueta:** Con pintura negra, dibuja una silueta simple en la parte inferior (un árbol solitario, montañas, una persona mirando al horizonte, un columpio…).
# 4. **Detalles opcionales:** Pequeñas estrellas blancas, una luna o pájaros.
#
# ---
#
# ¿Quieres que te dé otras ideas? Puedo sugerirte según tu estilo:
# - 🎨 **Abstracto** (manchas, geometría, texturas)
# - 🌸 **Floral** (flores sueltas, ramos)
# - 🐱 **Animales estilizados**
# ...

# %%
# Streaming 
messages = []
add_user_message(messages, "Escribe una oración sobre una falsa database")

with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages
) as stream:
    for text in stream.text_stream:
        print(text, end="")
# Out:
# Aquí tienes una oración sobre una falsa database:
#
# "El detective descubrió que la falsa database contenía nombres inventados y direcciones inexistentes, diseñada para engañar a los investigadores y desviar la atención del verdadero culpable."
#
# ¿Te gustaría que escriba más oraciones o que adapte el tono (técnico, narrativo, periodístico, etc.)?

# %%
# Streaming 
messages = []
add_user_message(messages, "Escribe una oración sobre una falsa database")
with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages
) as stream:
    for text in stream.text_stream:
        # Send each chunk to your client
        pass
    
    # Get the complete message for database storage
    final_message = stream.get_final_message()
    print(text, end="")
# Out:
#  alguna manera?

# %%
## datos estructurados

def chat(messages, system=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")

text = chat(messages, stop_sequences=["```"])
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[24], line 6
#       3 add_user_message(messages, "Generate a very short event bridge rule as json")
#       4 add_assistant_message(messages, "```json")
# ----> 6 text = chat(messages, stop_sequences=["```"])
#
# Cell In[22], line 15, in chat(messages, system, temperature, stop_sequences)
#      12 if stop_sequences:
#      13     params["stop_sequences"] = stop_sequences
# ---> 15 message = client.messages.create(**params)
#      16 return message.content[0].text
#
# File c:\Users\jerom\anaconda3\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# ...

# %%
messages = []
add_user_message(messages, "Generate a very short event bridge rule as json")

system = "Output only raw JSON. No markdown, no code blocks, no explanation. Just the JSON object."
text = chat(messages, system=system)

print(text)
# Out:
# {"Name":"DailyRule","ScheduleExpression":"rate(1 day)","State":"ENABLED","Targets":[{"Id":"1","Arn":"arn:aws:lambda:us-east-1:123456789012:function:MyFunc"}]}

# %%
import json

# Clean up and parse the JSON
clean_json = json.loads(text.strip())

clean_json
# Out:
# {'Name': 'DailyRule',
#  'ScheduleExpression': 'rate(1 day)',
#  'State': 'ENABLED',
#  'Targets': [{'Id': '1',
#    'Arn': 'arn:aws:lambda:us-east-1:123456789012:function:MyFunc'}]}
